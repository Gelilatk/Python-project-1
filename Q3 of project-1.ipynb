# %% [markdown]
# # 3. To-Do List App (Text-Based)
#     Build a to-do list manager that:
#         •	Allows users to add tasks with priorities (e.g., "Buy milk - high").
#         •	Lets them view the current list, delete tasks by number, and mark tasks as complete.
#         •	Keeps looping until the user types “exit”.
#         •	Shows a summary at the end: number of completed tasks vs pending.
# #### Skills practiced: lists, string parsing, loops, input, CRUD basics

# %%
# Step-1: Welcome message
print("============= Group Two's To-Do List =============")
print()

# Step - 2: Initialize task as an empty list
tasks = []
completed_tasks = []

# Step-3: Create a command lists that a user can practice in the To-Do activity
print("Available Commands in this To-Do List are: 'Add', 'Delete', 'View', 'Complete' and 'Exit'.")
print()

while True:
    # Step-4: Get commands from the user
    user_command = input('Please enter a command that you want to do: ').strip().lower()
    print()

    # Step-5: Use conditional formatting to execute the above five commands
    # For 'exit' condition
    if user_command == 'exit':
        break
    # For 'add' condition
    elif user_command == 'add':
        # Get task description and priority for the task from the user as in the example specification
        user_task = input('Enter tasks with priorities (e.g., "Buy milk - high"): ').strip().title()
        if ' - ' in user_task:
            tasks.append(user_task)
            print(f"Your task '{user_task}' is added to the tasks list")
            print()
        else:
            print(f'You entered incorrectly. Please make sure you entered the task as in the example format.')
            print()
    # For 'delete' condition
    elif user_command == 'delete':
        if not tasks:
            print('There is no any task in the list for deleting.')
            print()
        else:
            print(' ===== List of Tasks ==== ')
            i = 0
            for task in tasks:
                i += 1
                print(f"{i}. {task}")
            print()
            try:
                task_number = input('Please enter task number from the list of tasks above: ')
                task_number_int = int(task_number)
                if task_number_int in range(1, len(tasks)+1):
                    removed_task = tasks.pop(task_number_int - 1)
                    print(f"You delete the task '{removed_task}' from the task list.")
                    print()
                else:
                    print(f"You entered incorrect task number. Please use a number between 1 and {len(tasks)}.")
                    print()
            except ValueError:
                print('Invalid number. Please enter again.')
                print()
    # For 'view' condition
    elif user_command == 'view':
        if not tasks:
            print('There is no any task in the list to view.')
        else:
            print('List of Tasks')
            i = 0
            for task in tasks:
                i += 1
                print(f"{i}. {task}")
    # For 'complete' condition
    elif user_command == 'complete':
        if not tasks:
            print('There is no any task in the list to complete.')
        else:
            print(' ==== List of Tasks ====')
            i = 0
            for task in tasks:
                i += 1
                print(f"{i:}. {task}")
            print()
            try:
                task_number = input('Please enter task number from the above list of tasks you completed: ')
                task_number_int = int(task_number)
                if task_number_int in range(1, len(tasks)+1):
                    completed_task = tasks.pop(task_number_int - 1)
                    completed_tasks.append(completed_task)
                    print(f"You completed the task '{completed_task}' from the task list.")
                    print()
                else:
                    print(f"You entered incorrect task number. Please use a number between 1 and {len(tasks)}.")
                    print()
            except ValueError:
                print('Invalid number. Please enter again.')
                print()
    #For incorrect command input
    else:
        print(f'You entered incorrect command. {user_command} is not in the command list')
# Step-6: Print the To-Do List summary
print()
print(' ======================= Summary for the TO-DO List ======================= ') 
print(f"Total task listed = {len(tasks) + len(completed_tasks)}")
print() 

print(f"From total task listed, Completed tasks = {len(completed_tasks)}. \nSpecifically: ")
for task in completed_tasks:
    print(f"  - {task}")
print()
    
print(f"From total task listed, Pending tasks = {len(tasks)}. \nSpecifically: ")
for task in tasks:
    print(f"  - {task}")
# Out:
# ============= Group Two's To-Do List =============
#
# Available Commands in this To-Do List are: 'Add', 'Delete', 'View', 'Complete' and 'Exit'.
# Please enter a command that you want to do:  add
# Enter tasks with priorities (e.g., "Buy milk - high"):  Python project submission - critical
# Your task 'Python Project Submission - Critical' is added to the tasks list
# Please enter a command that you want to do:  add
# Enter tasks with priorities (e.g., "Buy milk - high"):  Project group meeting - critical
# Your task 'Project Group Meeting - Critical' is added to the tasks list
# Please enter a command that you want to do:  add
# Enter tasks with priorities (e.g., "Buy milk - high"):  Revise version control - high
# Your task 'Revise Version Control - High' is added to the tasks list
# Please enter a command that you want to do:  add
# Enter tasks with priorities (e.g., "Buy milk - high"):  Meet a friend - medium
# Your task 'Meet A Friend - Medium' is added to the tasks list
# Please enter a command that you want to do:  add
# Enter tasks with priorities (e.g., "Buy milk - high"):  Take a nap - medium
# Your task 'Take A Nap - Medium' is added to the tasks list
# Please enter a command that you want to do:  add
# Enter tasks with priorities (e.g., "Buy milk - high"):  Ironing - Low
# Your task 'Ironing - Low' is added to the tasks list
# Please enter a command that you want to do:  delete
#  ===== List of Tasks ====
# 1. Python Project Submission - Critical
# 2. Project Group Meeting - Critical
# 3. Revise Version Control - High
# 4. Meet A Friend - Medium
# 5. Take A Nap - Medium
# 6. Ironing - Low
# Please enter task number from the list of tasks above:  4
# You delete the task 'Meet A Friend - Medium' from the task list.
# Please enter a command that you want to do:  view
# List of Tasks
# 1. Python Project Submission - Critical
# 2. Project Group Meeting - Critical
# 3. Revise Version Control - High
# 4. Take A Nap - Medium
# 5. Ironing - Low
# Please enter a command that you want to do:  complete
#  ==== List of Tasks ====
# 1. Python Project Submission - Critical
# 2. Project Group Meeting - Critical
# 3. Revise Version Control - High
# 4. Take A Nap - Medium
# 5. Ironing - Low
# Please enter task number from the above list of tasks you completed:  2
# You completed the task 'Project Group Meeting - Critical' from the task list.
# Please enter a command that you want to do:  complete
#  ==== List of Tasks ====
# 1. Python Project Submission - Critical
# 2. Revise Version Control - High
# 3. Take A Nap - Medium
# 4. Ironing - Low
# Please enter task number from the above list of tasks you completed:  2
# You completed the task 'Revise Version Control - High' from the task list.
# Please enter a command that you want to do:  exit
#  ======================= Summary for the TO-DO List =======================
# Total task listed = 5
#
# From total task listed, Completed tasks = 2.
# Specifically:
#   - Project Group Meeting - Critical
#   - Revise Version Control - High
#
# From total task listed, Pending tasks = 3.
# Specifically:
#   - Python Project Submission - Critical
#   - Take A Nap - Medium
#   - Ironing - Low
